# %% [markdown]
# ## Modules and Packages

# %%
def addition(num1, num2):
    return num1 + num2

# %%
addition(4, 5)
# Out:
# 9

# %% [markdown]
# I want to use this logic of the function in this file into the other files

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %% [markdown]
# ### Module
# A Module in python is simply a file containing python code (functions, classes or variables) that can be imported and used in other programs
#
#     - A module helps in code organization
#     - It promotes reusablity
#     - It keeps the code clean and managebable
#
# #### Numpy --->
# - 1. Numpy module is going to help us out with applying scientific calculation on the array and we can store our data by consuming less space and we can apply operations with our array a bit more faster as compared to those of the list
# - 2. We can Do it in Numpy just because numpy is having the collection of functions and attributes which can help us to work effeciently with the array

# %% [markdown]
# ### Pandas --->
# - 1. Pandas we can use when we are going to work with the dataset for cleaning, pre processing, EDA, analysis with plotting as well

# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt
sqrt(6)
# Out:
# 2.449489742783178

# %%
from math import *

# %%
import numpy

# %%
list_items=[[1,2,3,4,5]]
numpy_array=numpy.array(list_items)
print(numpy_array)
# Out:
# [[1 2 3 4 5]]

# %%
print(type(numpy_array))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# I am trying to create my own library or module and in this library i want the function and the attributes to be created on my own

# %% [markdown]
# __init__.py is a file that has to be their inside the package folder and this __init__.py file helps us out in defining our packages and initializing their neamespaces

# %% [markdown]
# __init__.py file can remain empty and its compleatly fine but this file has to be their
# when we will be creating out new packages into the package folder
