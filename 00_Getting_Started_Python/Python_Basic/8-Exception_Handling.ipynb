# %% [markdown]
# ## Exception Handling

# %%
Denominator=num= int(input("Hello Please Enter the denominator for division"))
result=1/Denominator
print(result)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 Denominator=num= int(input("Hello Please Enter the denominator for division"))
# ----> 2 result=1/Denominator
#       3 print(result)
#
# ZeroDivisionError: division by zero

# %%
## Exception handling is a way in which if we are getting the Errors in programming or if the user entered input cause an error, then instead of Throwing an Error we can raise an 
## exception which can let the user know that the input is not correct or the given input can come up as an Error. As we dont want to stop the execution of the program,
## so we raise an error which will let the user know that the current input is not correct but the program executon wont stop.

# %%
### Execption are events that disrupt the normal flow of a program. They occur when an error is encountered during program execution.except

# %% [markdown]
# ### Different Types of Execption:

# %% [markdown]
# 1. ZeroDivisionError --> Dividing by zero
# 2. FileNotFoundError --> File Not Found
# 3. ValueError --> Invalid Value
# 4. TypeError --> Invalid Type

# %% [markdown]
# ### try Except Block

# %%
try:
    x = 10 / 0
except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %% [markdown]
# ### Multiple Exception

# %%
try:
    num = int(input("Enter number: "))
    result = 10 / num

except ValueError:
    print("Please enter a number")

except ZeroDivisionError:
    print("Cannot divide by zero")
# Out:
# Cannot divide by zero

# %% [markdown]
# ### Finally

# %%
try:
    file = open("data.txt")
except FileNotFoundError:
    print("File not found")
finally:
    print("Execution completed")
# Out:
# File not found
# Execution completed

# %% [markdown]
# ### raise

# %%
age = 15

if age < 18:
    raise ValueError("Age must be 18 or above")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 age = 15
#       2
#       3 if age < 18:
# ----> 4     raise ValueError("Age must be 18 or above")
#
# ValueError: Age must be 18 or above

# %% [markdown]
# ### Custome Exception

# %%
class InsufficientBalanceError(Exception):
    pass

balance = 500

if balance < 1000:
    raise InsufficientBalanceError("Insufficient balance")
# Out:
# ---------------------------------------------------------------------------
# InsufficientBalanceError                  Traceback (most recent call last)
# Cell In[11], line 7
#       3
#       4 balance = 500
#       5
#       6 if balance < 1000:
# ----> 7     raise InsufficientBalanceError("Insufficient balance")
#
# InsufficientBalanceError: Insufficient balance

# %% [markdown]
# ### Generic

# %%
try:
    x = 10 / 0
except Exception as e:
    print(e)
# Out:
# division by zero
